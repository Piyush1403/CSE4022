# %% [markdown]
# # Simple name classification using nltk

# %%
import nltk

# %%
from nltk.corpus import names

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Sherlock')
# Out:
# {'last_letter': 'k'}

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + 
                [(name, 'female') for name in names.words('female.txt')])

# %%
labeled_names
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male'),
#  ('Abdullah', 'male'),
#  ('Abe', 'male'),
#  ('Abel', 'male'),
#  ('Abelard', 'male'),
#  ('Abner', 'male'),
#  ('Abraham', 'male'),
#  ('Abram', 'male'),
#  ('Ace', 'male'),
#  ('Adair', 'male'),
#  ('Adam', 'male'),
#  ('Adams', 'male'),
#  ('Addie', 'male'),
#  ('Adger', 'male'),
#  ('Aditya', 'male'),
#  ('Adlai', 'male'),
#  ('Adnan', 'male'),
#  ('Adolf', 'male'),
#  ('Adolfo', 'male'),
#  ('Adolph', 'male'),
#  ('Adolphe', 'male'),
#  ('Adolpho', 'male'),
#  ('Adolphus', 'male'),
#  ('Adrian', 'male'),
#  ('Adrick', 'male'),
#  ('Adrien', 'male'),
#  ('Agamemnon', 'male'),
#  ('Aguinaldo', 'male'),
#  ('Aguste', 'male'),
#  ('Agustin', 'male'),
#  ('Aharon', 'male'),
#  ('Ahmad', 'male'),
#  ('Ahmed', 'male'),
#  ('Ahmet', 'male'),
#  ('Ajai', 'male'),
#  ('Ajay', 'male'),
#  ('Al', 'male'),
#  ('Alaa', 'male'),
#  ('Alain', 'male'),
#  ('Alan', 'male'),
#  ('Alasdair', 'male'),
#  ('Alastair', 'male'),
#  ('Albatros', 'male'),
#  ('Albert', 'male'),
#  ('Alberto', 'male'),
#  ('Albrecht', 'male'),
#  ('Alden', 'male'),
#  ('Aldis', 'male'),
#  ('Aldo', 'male'),
#  ('Aldric', 'male'),
#  ('Aldrich', 'male'),
#  ('Aldus', 'male'),
#  ('Aldwin', 'male'),
#  ('Alec', 'male'),
#  ('Aleck', 'male'),
#  ('Alejandro', 'male'),
#  ('Aleks', 'male'),
#  ('Aleksandrs', 'male'),
#  ('Alessandro', 'male'),
#  ('Alex', 'male'),
#  ('Alexander', 'male'),
#  ('Alexei', 'male'),
#  ('Alexis', 'male'),
#  ('Alf', 'male'),
#  ('Alfie', 'male'),
#  ('Alfonse', 'male'),
#  ('Alfonso', 'male'),
#  ('Alfonzo', 'male'),
#  ('Alford', 'male'),
#  ('Alfred', 'male'),
#  ('Alfredo', 'male'),
#  ('Algernon', 'male'),
#  ('Ali', 'male'),
#  ('Alic', 'male'),
#  ('Alister', 'male'),
#  ('Alix', 'male'),
#  ('Allah', 'male'),
#  ('Allan', 'male'),
#  ('Allen', 'male'),
#  ('Alley', 'male'),
#  ('Allie', 'male'),
#  ('Allin', 'male'),
#  ('Allyn', 'male'),
#  ('Alonso', 'male'),
#  ('Alonzo', 'male'),
#  ('Aloysius', 'male'),
#  ('Alphonse', 'male'),
#  ('Alphonso', 'male'),
#  ('Alston', 'male'),
#  ('Alton', 'male'),
#  ('Alvin', 'male'),
#  ('Alwin', 'male'),
#  ('Amadeus', 'male'),
#  ('Ambros', 'male'),
#  ('Ambrose', 'male'),
#  ('Ambrosi', 'male'),
#  ('Ambrosio', 'male'),
#  ('Ambrosius', 'male'),
#  ('Amery', 'male'),
#  ('Amory', 'male'),
#  ('Amos', 'male'),
#  ('Anatol', 'male'),
#  ('Anatole', 'male'),
#  ('Anatollo', 'male'),
#  ('Anatoly', 'male'),
#  ('Anders', 'male'),
#  ('Andie', 'male'),
#  ('Andonis', 'male'),
#  ('Andre', 'male'),
#  ('Andrea', 'male'),
#  ('Andreas', 'male'),
#  ('Andrej', 'male'),
#  ('Andres', 'male'),
#  ('Andrew', 'male'),
#  ('Andrey', 'male'),
#  ('Andri', 'male'),
#  ('Andros', 'male'),
#  ('Andrus', 'male'),
#  ('Andrzej', 'male'),
#  ('Andy', 'male'),
#  ('Angel', 'male'),
#  ('Angelico', 'male'),
#  ('Angelo', 'male'),
#  ('Angie', 'male'),
#  ('Angus', 'male'),
#  ('Ansel', 'male'),
#  ('Ansell', 'male'),
#  ('Anselm', 'male'),
#  ('Anson', 'male'),
#  ('Anthony', 'male'),
#  ('Antin', 'male'),
#  ('Antoine', 'male'),
#  ('Anton', 'male'),
#  ('Antone', 'male'),
#  ('Antoni', 'male'),
#  ('Antonin', 'male'),
#  ('Antonino', 'male'),
#  ('Antonio', 'male'),
#  ('Antonius', 'male'),
#  ('Antony', 'male'),
#  ('Anurag', 'male'),
#  ('Apollo', 'male'),
#  ('Apostolos', 'male'),
#  ('Aram', 'male'),
#  ('Archibald', 'male'),
#  ('Archibold', 'male'),
#  ('Archie', 'male'),
#  ('Archon', 'male'),
#  ('Archy', 'male'),
#  ('Arel', 'male'),
#  ('Ari', 'male'),
#  ('Arie', 'male'),
#  ('Ariel', 'male'),
#  ('Aristotle', 'male'),
#  ('Arlo', 'male'),
#  ('Armand', 'male'),
#  ('Armando', 'male'),
#  ('Armond', 'male'),
#  ('Armstrong', 'male'),
#  ('Arne', 'male'),
#  ('Arnie', 'male'),
#  ('Arnold', 'male'),
#  ('Arnoldo', 'male'),
#  ('Aron', 'male'),
#  ('Arron', 'male'),
#  ('Art', 'male'),
#  ('Arther', 'male'),
#  ('Arthur', 'male'),
#  ('Artie', 'male'),
#  ('Artur', 'male'),
#  ('Arturo', 'male'),
#  ('Arvie', 'male'),
#  ('Arvin', 'male'),
#  ('Arvind', 'male'),
#  ('Arvy', 'male'),
#  ('Ash', 'male'),
#  ('Ashby', 'male'),
#  ('Ashish', 'male'),
#  ('Ashley', 'male'),
#  ('Ashton', 'male'),
#  ('Aub', 'male'),
#  ('Aube', 'male'),
#  ('Aubert', 'male'),
#  ('Aubrey', 'male'),
#  ('Augie', 'male'),
#  ('August', 'male'),
#  ('Augustin', 'male'),
#  ('Augustine', 'male'),
#  ('Augusto', 'male'),
#  ('Augustus', 'male'),
#  ('Austen', 'male'),
#  ('Austin', 'male'),
#  ('Ave', 'male'),
#  ('Averell', 'male'),
#  ('Averil', 'male'),
#  ('Averill', 'male'),
#  ('Avery', 'male'),
#  ('Avi', 'male'),
#  ('Avraham', 'male'),
#  ('Avram', 'male'),
#  ('Avrom', 'male'),
#  ('Axel', 'male'),
#  ('Aylmer', 'male'),
#  ('Aziz', 'male'),
#  ('Bailey', 'male'),
#  ('Bailie', 'male'),
#  ('Baillie', 'male'),
#  ('Baily', 'male'),
#  ('Baird', 'male'),
#  ('Baldwin', 'male'),
#  ('Bancroft', 'male'),
#  ('Barbabas', 'male'),
#  ('Barclay', 'male'),
#  ('Bard', 'male'),
#  ('Barde', 'male'),
#  ('Barn', 'male'),
#  ('Barnabas', 'male'),
#  ('Barnabe', 'male'),
#  ('Barnaby', 'male'),
#  ('Barnard', 'male'),
#  ('Barnebas', 'male'),
#  ('Barnett', 'male'),
#  ('Barney', 'male'),
#  ('Barnie', 'male'),
#  ('Barny', 'male'),
#  ('Baron', 'male'),
#  ('Barr', 'male'),
#  ('Barret', 'male'),
#  ('Barrett', 'male'),
#  ('Barri', 'male'),
#  ('Barrie', 'male'),
#  ('Barris', 'male'),
#  ('Barron', 'male'),
#  ('Barry', 'male'),
#  ('Bart', 'male'),
#  ('Bartel', 'male'),
#  ('Barth', 'male'),
#  ('Barthel', 'male'),
#  ('Bartholemy', 'male'),
#  ('Bartholomeo', 'male'),
#  ('Bartholomeus', 'male'),
#  ('Bartholomew', 'male'),
#  ('Bartie', 'male'),
#  ('Bartlet', 'male'),
#  ('Bartlett', 'male'),
#  ('Bartolemo', 'male'),
#  ('Bartolomei', 'male'),
#  ('Bartolomeo', 'male'),
#  ('Barton', 'male'),
#  ('Barty', 'male'),
#  ('Bary', 'male'),
#  ('Basil', 'male'),
#  ('Batholomew', 'male'),
#  ('Baxter', 'male'),
#  ('Bay', 'male'),
#  ('Bayard', 'male'),
#  ('Beale', 'male'),
#  ('Bealle', 'male'),
#  ('Bear', 'male'),
#  ('Bearnard', 'male'),
#  ('Beau', 'male'),
#  ('Beaufort', 'male'),
#  ('Beauregard', 'male'),
#  ('Beck', 'male'),
#  ('Bela', 'male'),
#  ('Ben', 'male'),
#  ('Benedict', 'male'),
#  ('Bengt', 'male'),
#  ('Benito', 'male'),
#  ('Benjamen', 'male'),
#  ('Benjamin', 'male'),
#  ('Benji', 'male'),
#  ('Benjie', 'male'),
#  ('Benjy', 'male'),
#  ('Benn', 'male'),
#  ('Bennet', 'male'),
#  ('Bennett', 'male'),
#  ('Bennie', 'male'),
#  ('Benny', 'male'),
#  ('Benson', 'male'),
#  ('Bentley', 'male'),
#  ('Benton', 'male'),
#  ('Beowulf', 'male'),
#  ('Berchtold', 'male'),
#  ('Berk', 'male'),
#  ('Berke', 'male'),
#  ('Berkeley', 'male'),
#  ('Berkie', 'male'),
#  ('Berkley', 'male'),
#  ('Bernard', 'male'),
#  ('Bernardo', 'male'),
#  ('Bernd', 'male'),
#  ('Bernhard', 'male'),
#  ('Bernie', 'male'),
#  ('Bert', 'male'),
#  ('Bertie', 'male'),
#  ('Bertram', 'male'),
#  ('Bertrand', 'male'),
#  ('Bharat', 'male'),
#  ('Biff', 'male'),
#  ('Bill', 'male'),
#  ('Billie', 'male'),
#  ('Billy', 'male'),
#  ('Bing', 'male'),
#  ('Binky', 'male'),
#  ('Bishop', 'male'),
#  ('Bjorn', 'male'),
#  ('Bjorne', 'male'),
#  ('Blaine', 'male'),
#  ('Blair', 'male'),
#  ('Blake', 'male'),
#  ('Blare', 'male'),
#  ('Blayne', 'male'),
#  ('Bo', 'male'),
#  ('Bob', 'male'),
#  ('Bobbie', 'male'),
#  ('Bobby', 'male'),
#  ('Bogart', 'male'),
#  ('Bogdan', 'male'),
#  ('Boniface', 'male'),
#  ('Boris', 'male'),
#  ('Boyce', 'male'),
#  ('Boyd', 'male'),
#  ('Brad', 'male'),
#  ('Braden', 'male'),
#  ('Bradford', 'male'),
#  ('Bradley', 'male'),
#  ('Bradly', 'male'),
#  ('Brady', 'male'),
#  ('Brandon', 'male'),
#  ('Brandy', 'male'),
#  ('Brant', 'male'),
#  ('Brendan', 'male'),
#  ('Brent', 'male'),
#  ('Bret', 'male'),
#  ('Brett', 'male'),
#  ('Brewer', 'male'),
#  ('Brewster', 'male'),
#  ('Brian', 'male'),
#  ('Brice', 'male'),
#  ('Briggs', 'male'),
#  ('Brinkley', 'male'),
#  ('Britt', 'male'),
#  ('Brock', 'male'),
#  ('Broddie', 'male'),
#  ('Broddy', 'male'),
#  ('Broderic', 'male'),
#  ('Broderick', 'male'),
#  ('Brodie', 'male'),
#  ('Brody', 'male'),
#  ('Bronson', 'male'),
#  ('Brook', 'male'),
#  ('Brooke', 'male'),
#  ('Brooks', 'male'),
#  ('Bruce', 'male'),
#  ('Bruno', 'male'),
#  ('Bryan', 'male'),
#  ('Bryant', 'male'),
#  ('Bryce', 'male'),
#  ('Bryn', 'male'),
#  ('Bryon', 'male'),
#  ('Bubba', 'male'),
#  ('Buck', 'male'),
#  ('Bucky', 'male'),
#  ('Bud', 'male'),
#  ('Buddy', 'male'),
#  ('Burgess', 'male'),
#  ('Burke', 'male'),
#  ('Burl', 'male'),
#  ('Burnaby', 'male'),
#  ('Burt', 'male'),
#  ('Burton', 'male'),
#  ('Buster', 'male'),
#  ('Butch', 'male'),
#  ('Butler', 'male'),
#  ('Byram', 'male'),
#  ('Byron', 'male'),
#  ('Caesar', 'male'),
#  ('Cain', 'male'),
#  ('Cal', 'male'),
#  ('Caldwell', 'male'),
#  ('Caleb', 'male'),
#  ('Calhoun', 'male'),
#  ('Calvin', 'male'),
#  ('Cam', 'male'),
#  ('Cameron', 'male'),
#  ('Cammy', 'male'),
#  ('Carey', 'male'),
#  ('Carl', 'male'),
#  ('Carleigh', 'male'),
#  ('Carlie', 'male'),
#  ('Carlin', 'male'),
#  ('Carlo', 'male'),
#  ('Carlos', 'male'),
#  ('Carlton', 'male'),
#  ('Carlyle', 'male'),
#  ('Carmine', 'male'),
#  ('Carroll', 'male'),
#  ('Carson', 'male'),
#  ('Carsten', 'male'),
#  ('Carter', 'male'),
#  ('Cary', 'male'),
#  ('Caryl', 'male'),
#  ('Case', 'male'),
#  ('Casey', 'male'),
#  ('Caspar', 'male'),
#  ('Casper', 'male'),
#  ('Cass', 'male'),
#  ('Cat', 'male'),
#  ('Cecil', 'male'),
#  ('Cesar', 'male'),
#  ('Chad', 'male'),
#  ('Chadd', 'male'),
#  ('Chaddie', 'male'),
#  ('Chaddy', 'male'),
#  ('Chadwick', 'male'),
#  ('Chaim', 'male'),
#  ('Chalmers', 'male'),
#  ('Chan', 'male'),
#  ('Chance', 'male'),
#  ('Chancey', 'male'),
#  ('Chanderjit', 'male'),
#  ('Chandler', 'male'),
#  ('Chane', 'male'),
#  ('Chariot', 'male'),
#  ('Charles', 'male'),
#  ('Charleton', 'male'),
#  ('Charley', 'male'),
#  ('Charlie', 'male'),
#  ('Charlton', 'male'),
#  ('Chas', 'male'),
#  ('Chase', 'male'),
#  ('Chaunce', 'male'),
#  ('Chauncey', 'male'),
#  ('Che', 'male'),
#  ('Chelton', 'male'),
#  ('Chen', 'male'),
#  ('Chester', 'male'),
#  ('Cheston', 'male'),
#  ('Chet', 'male'),
#  ('Chev', 'male'),
#  ('Chevalier', 'male'),
#  ('Chevy', 'male'),
#  ('Chip', 'male'),
#  ('Chris', 'male'),
#  ('Chrissy', 'male'),
#  ('Christ', 'male'),
#  ('Christian', 'male'),
#  ('Christiano', 'male'),
#  ('Christie', 'male'),
#  ('Christof', 'male'),
#  ('Christofer', 'male'),
#  ('Christoph', 'male'),
#  ('Christophe', 'male'),
#  ('Christopher', 'male'),
#  ('Christorpher', 'male'),
#  ('Christos', 'male'),
#  ('Christy', 'male'),
#  ('Chrisy', 'male'),
#  ('Chuck', 'male'),
#  ('Churchill', 'male'),
#  ('Clair', 'male'),
#  ('Claire', 'male'),
#  ('Clancy', 'male'),
#  ('Clarance', 'male'),
#  ('Clare', 'male'),
#  ('Clarence', 'male'),
#  ('Clark', 'male'),
#  ('Clarke', 'male'),
#  ('Claude', 'male'),
#  ('Claudio', 'male'),
#  ('Claudius', 'male'),
#  ('Claus', 'male'),
#  ('Clay', 'male'),
#  ('Clayborn', 'male'),
#  ('Clayborne', 'male'),
#  ('Claybourne', 'male'),
#  ('Clayton', 'male'),
#  ('Cleland', 'male'),
#  ('Clem', 'male'),
#  ('Clemens', 'male'),
#  ('Clement', 'male'),
#  ('Clemente', 'male'),
#  ('Clemmie', 'male'),
#  ('Cletus', 'male'),
#  ('Cleveland', 'male'),
#  ('Cliff', 'male'),
#  ('Clifford', 'male'),
#  ('Clifton', 'male'),
#  ('Clint', 'male'),
#  ('Clinten', 'male'),
#  ('Clinton', 'male'),
#  ('Clive', 'male'),
#  ('Clyde', 'male'),
#  ('Cob', 'male'),
#  ('Cobb', 'male'),
#  ('Cobbie', 'male'),
#  ('Cobby', 'male'),
#  ('Cody', 'male'),
#  ('Colbert', 'male'),
#  ('Cole', 'male'),
#  ('Coleman', 'male'),
#  ('Colin', 'male'),
#  ('Collin', 'male'),
#  ('Collins', 'male'),
#  ('Conan', 'male'),
#  ('Connie', 'male'),
#  ('Connolly', 'male'),
#  ('Connor', 'male'),
#  ('Conrad', 'male'),
#  ('Conroy', 'male'),
#  ('Constantin', 'male'),
#  ('Constantine', 'male'),
#  ('Constantinos', 'male'),
#  ('Conway', 'male'),
#  ('Cooper', 'male'),
#  ('Corbin', 'male'),
#  ('Corby', 'male'),
#  ('Corey', 'male'),
#  ('Corky', 'male'),
#  ('Cornelius', 'male'),
#  ('Cornellis', 'male'),
#  ('Corrie', 'male'),
#  ('Cortese', 'male'),
#  ('Corwin', 'male'),
#  ('Cory', 'male'),
#  ('Cosmo', 'male'),
#  ('Costa', 'male'),
#  ('Courtney', 'male'),
#  ('Craig', 'male'),
#  ('Crawford', 'male'),
#  ('Creighton', 'male'),
#  ('Cris', 'male'),
#  ('Cristopher', 'male'),
#  ('Curt', 'male'),
#  ('Curtice', 'male'),
#  ('Curtis', 'male'),
#  ('Cy', 'male'),
#  ('Cyril', 'male'),
#  ('Cyrill', 'male'),
#  ('Cyrille', 'male'),
#  ('Cyrillus', 'male'),
#  ('Cyrus', 'male'),
#  ('Dabney', 'male'),
#  ('Daffy', 'male'),
#  ('Dale', 'male'),
#  ('Dallas', 'male'),
#  ('Dalton', 'male'),
#  ('Damian', 'male'),
#  ('Damien', 'male'),
#  ('Damon', 'male'),
#  ('Dan', 'male'),
#  ('Dana', 'male'),
#  ('Dane', 'male'),
#  ('Dani', 'male'),
#  ('Danie', 'male'),
#  ('Daniel', 'male'),
#  ('Dannie', 'male'),
#  ('Danny', 'male'),
#  ('Dante', 'male'),
#  ('Darby', 'male'),
#  ('Darcy', 'male'),
#  ('Daren', 'male'),
#  ('Darian', 'male'),
#  ('Darien', 'male'),
#  ('Darin', 'male'),
#  ('Dario', 'male'),
#  ('Darius', 'male'),
#  ('Darrel', 'male'),
#  ('Darrell', 'male'),
#  ('Darren', 'male'),
#  ('Darrick', 'male'),
#  ('Darrin', 'male'),
#  ('Darryl', 'male'),
#  ('Darth', 'male'),
#  ('Darwin', 'male'),
#  ('Daryl', 'male'),
#  ('Daryle', 'male'),
#  ('Dave', 'male'),
#  ('Davey', 'male'),
#  ('David', 'male'),
#  ('Davidde', 'male'),
#  ('Davide', 'male'),
#  ('Davidson', 'male'),
#  ('Davie', 'male'),
#  ('Davin', 'male'),
#  ('Davis', 'male'),
#  ('Davon', 'male'),
#  ('Davoud', 'male'),
#  ('Davy', 'male'),
#  ('Dawson', 'male'),
#  ('Dean', 'male'),
#  ('Deane', 'male'),
#  ('Del', 'male'),
#  ('Delbert', 'male'),
#  ('Dell', 'male'),
#  ('Delmar', 'male'),
#  ('Demetre', 'male'),
#  ('Demetri', 'male'),
#  ('Demetris', 'male'),
#  ('Demetrius', 'male'),
#  ('Demosthenis', 'male'),
#  ('Denis', 'male'),
#  ('Dennie', 'male'),
#  ('Dennis', 'male'),
#  ('Denny', 'male'),
#  ('Derby', 'male'),
#  ('Derek', 'male'),
#  ('Derick', 'male'),
#  ('Derk', 'male'),
#  ('Derrek', 'male'),
#  ('Derrick', 'male'),
#  ('Derrin', 'male'),
#  ('Derrol', 'male'),
#  ('Derron', 'male'),
#  ('Deryl', 'male'),
#  ('Desmond', 'male'),
#  ('Desmund', 'male'),
#  ('Devin', 'male'),
#  ('Devon', 'male'),
#  ('Dewey', 'male'),
#  ('Dewitt', 'male'),
#  ('Dexter', 'male'),
#  ('Dick', 'male'),
#  ('Dickey', 'male'),
#  ('Dickie', 'male'),
#  ('Diego', 'male'),
#  ('Dieter', 'male'),
#  ('Dietrich', 'male'),
#  ('Dillon', 'male'),
#  ('Dimitri', 'male'),
#  ('Dimitrios', 'male'),
#  ('Dimitris', 'male'),
#  ('Dimitrou', 'male'),
#  ('Dimitry', 'male'),
#  ('Dino', 'male'),
#  ('Dion', 'male'),
#  ('Dionis', 'male'),
#  ('Dionysus', 'male'),
#  ('Dirk', 'male'),
#  ('Dmitri', 'male'),
#  ('Dom', 'male'),
#  ('Domenic', 'male'),
#  ('Domenico', 'male'),
#  ('Dominic', 'male'),
#  ('Dominick', 'male'),
#  ('Dominique', 'male'),
#  ('Don', 'male'),
#  ('Donal', 'male'),
#  ('Donald', 'male'),
#  ('Donn', 'male'),
#  ('Donnie', 'male'),
#  ('Donny', 'male'),
#  ('Donovan', 'male'),
#  ('Dorian', 'male'),
#  ('Dory', 'male'),
#  ('Doug', 'male'),
#  ('Douggie', 'male'),
#  ('Dougie', 'male'),
#  ('Douglas', 'male'),
#  ('Douglass', 'male'),
#  ('Douglis', 'male'),
#  ('Dov', 'male'),
#  ('Doyle', 'male'),
#  ('Drake', 'male'),
#  ('Drew', 'male'),
#  ('Dru', 'male'),
#  ('Dryke', 'male'),
#  ('Duane', 'male'),
#  ('Dudley', 'male'),
#  ('Duffie', 'male'),
#  ('Duffy', 'male'),
#  ('Dugan', 'male'),
#  ('Duke', 'male'),
#  ('Dunc', 'male'),
#  ('Duncan', 'male'),
#  ('Dunstan', 'male'),
#  ('Durand', 'male'),
#  ('Durant', 'male'),
#  ('Durante', 'male'),
#  ('Durward', 'male'),
#  ('Dustin', 'male'),
#  ('Dwain', 'male'),
#  ('Dwaine', 'male'),
#  ('Dwane', 'male'),
#  ('Dwayne', 'male'),
#  ('Dwight', 'male'),
#  ('Dylan', 'male'),
#  ('Dyson', 'male'),
#  ('Earl', 'male'),
#  ('Earle', 'male'),
#  ('Easton', 'male'),
#  ('Eben', 'male'),
#  ('Ebeneser', 'male'),
#  ('Ebenezer', 'male'),
#  ('Eberhard', 'male'),
#  ('Ed', 'male'),
#  ('Eddie', 'male'),
#  ('Eddy', 'male'),
#  ('Edgar', 'male'),
#  ('Edgardo', 'male'),
#  ('Edie', 'male'),
#  ('Edmond', 'male'),
#  ('Edmund', 'male'),
#  ('Edouard', 'male'),
#  ('Edsel', 'male'),
#  ('Eduard', 'male'),
#  ('Eduardo', 'male'),
#  ('Edward', 'male'),
#  ('Edwin', 'male'),
#  ('Efram', 'male'),
#  ('Egbert', 'male'),
#  ('Ehud', 'male'),
#  ('Elbert', 'male'),
#  ('Elden', 'male'),
#  ('Eldon', 'male'),
#  ('Eli', 'male'),
#  ('Elias', 'male'),
#  ('Elihu', 'male'),
#  ('Elijah', 'male'),
#  ('Eliot', 'male'),
#  ('Eliott', 'male'),
#  ('Elisha', 'male'),
#  ('Elliot', 'male'),
#  ('Elliott', 'male'),
#  ('Ellis', 'male'),
#  ('Ellsworth', 'male'),
#  ('Ellwood', 'male'),
#  ('Elmer', 'male'),
#  ('Elmore', 'male'),
#  ('Elnar', 'male'),
#  ('Elric', 'male'),
#  ('Elroy', 'male'),
#  ('Elton', 'male'),
#  ('Elvin', 'male'),
#  ('Elvis', 'male'),
#  ('Elwin', 'male'),
#  ('Elwood', 'male'),
#  ('Elwyn', 'male'),
#  ('Ely', 'male'),
#  ('Emanuel', 'male'),
#  ('Emerson', 'male'),
#  ('Emery', 'male'),
#  ('Emil', 'male'),
#  ('Emile', 'male'),
#  ('Emilio', 'male'),
#  ('Emmanuel', 'male'),
#  ('Emmery', 'male'),
#  ('Emmet', 'male'),
#  ('Emmett', 'male'),
#  ('Emmit', 'male'),
#  ('Emmott', 'male'),
#  ('Emmy', 'male'),
#  ('Emory', 'male'),
#  ('Ender', 'male'),
#  ('Engelbart', 'male'),
#  ('Engelbert', 'male'),
#  ('Englebart', 'male'),
#  ('Englebert', 'male'),
#  ('Enoch', 'male'),
#  ('Enrico', 'male'),
#  ('Enrique', 'male'),
#  ('Ephraim', 'male'),
#  ('Ephram', 'male'),
#  ('Ephrayim', 'male'),
#  ('Ephrem', 'male'),
#  ('Er', 'male'),
#  ('Erasmus', 'male'),
#  ('Erastus', 'male'),
#  ('Erek', 'male'),
#  ('Erhard', 'male'),
#  ('Erhart', 'male'),
#  ('Eric', 'male'),
#  ('Erich', 'male'),
#  ('Erick', 'male'),
#  ('Erik', 'male'),
#  ('Erin', 'male'),
#  ('Erl', 'male'),
#  ('Ernest', 'male'),
#  ('Ernesto', 'male'),
#  ('Ernie', 'male'),
#  ('Ernst', 'male'),
#  ('Erny', 'male'),
#  ('Errol', 'male'),
#  ('Ervin', 'male'),
#  ('Erwin', 'male'),
#  ('Esau', 'male'),
#  ('Esme', 'male'),
#  ('Esteban', 'male'),
#  ('Ethan', 'male'),
#  ('Ethelbert', 'male'),
#  ('Ethelred', 'male'),
#  ('Etienne', 'male'),
#  ('Euclid', 'male'),
#  ('Eugen', 'male'),
#  ('Eugene', 'male'),
#  ('Eustace', 'male'),
#  ('Ev', 'male'),
#  ('Evan', 'male'),
#  ('Evelyn', 'male'),
#  ('Everard', 'male'),
#  ('Everett', 'male'),
#  ('Ewan', 'male'),
#  ('Ewart', 'male'),
#  ('Ez', 'male'),
#  ('Ezechiel', 'male'),
#  ('Ezekiel', 'male'),
#  ('Ezra', 'male'),
#  ('Fabian', 'male'),
#  ('Fabio', 'male'),
#  ('Fairfax', 'male'),
#  ('Farley', 'male'),
#  ('Fazeel', 'male'),
#  ('Federico', 'male'),
#  ('Felice', 'male'),
#  ('Felicio', 'male'),
#  ('Felipe', 'male'),
#  ('Felix', 'male'),
#  ('Ferd', 'male'),
#  ('Ferdie', 'male'),
#  ('Ferdinand', 'male'),
#  ('Ferdy', 'male'),
#  ('Fergus', 'male'),
#  ('Ferguson', 'male'),
#  ('Ferinand', 'male'),
#  ('Fernando', 'male'),
#  ('Fidel', 'male'),
#  ('Filbert', 'male'),
#  ('Filip', 'male'),
#  ('Filipe', 'male'),
#  ('Filmore', 'male'),
#  ('Finley', 'male'),
#  ('Finn', 'male'),
#  ('Fitz', 'male'),
#  ('Fitzgerald', 'male'),
#  ('Flem', 'male'),
#  ('Fleming', 'male'),
#  ('Flemming', 'male'),
#  ('Fletch', 'male'),
#  ('Fletcher', 'male'),
#  ('Flin', 'male'),
#  ('Flinn', 'male'),
#  ('Flint', 'male'),
#  ('Flipper', 'male'),
#  ('Florian', 'male'),
#  ('Floyd', 'male'),
#  ('Flynn', 'male'),
#  ('Fons', 'male'),
#  ('Fonsie', 'male'),
#  ('Fonz', 'male'),
#  ('Fonzie', 'male'),
#  ('Forbes', 'male'),
#  ('Ford', 'male'),
#  ('Forest', 'male'),
#  ('Forester', 'male'),
#  ('Forrest', 'male'),
#  ('Forrester', 'male'),
#  ('Forster', 'male'),
#  ('Foster', 'male'),
#  ('Fowler', 'male'),
#  ('Fox', 'male'),
#  ('Fran', 'male'),
#  ('Francesco', 'male'),
#  ('Francis', 'male'),
#  ('Francisco', 'male'),
#  ('Francois', 'male'),
#  ('Frank', 'male'),
#  ('Frankie', 'male'),
#  ('Franklin', 'male'),
#  ('Franklyn', 'male'),
#  ('Franky', 'male'),
#  ('Frans', 'male'),
#  ('Franz', 'male'),
#  ('Fraser', 'male'),
#  ('Frazier', 'male'),
#  ('Fred', 'male'),
#  ('Freddie', 'male'),
#  ('Freddy', 'male'),
#  ('Frederic', 'male'),
#  ('Frederich', 'male'),
#  ('Frederick', 'male'),
#  ('Frederico', 'male'),
#  ('Frederik', 'male'),
#  ('Fredric', 'male'),
#  ('Fredrick', 'male'),
#  ('Freeman', 'male'),
#  ('Freemon', 'male'),
#  ('Fremont', 'male'),
#  ('French', 'male'),
#  ('Friedric', 'male'),
#  ('Friedrich', 'male'),
#  ('Friedrick', 'male'),
#  ('Fritz', 'male'),
#  ('Fulton', 'male'),
#  ('Fyodor', 'male'),
#  ('Gabe', 'male'),
#  ('Gabriel', 'male'),
#  ('Gabriele', 'male'),
#  ('Gabriell', 'male'),
#  ('Gabriello', 'male'),
#  ('Gail', 'male'),
#  ('Gale', 'male'),
#  ('Galen', 'male'),
#  ('Gallagher', 'male'),
#  ('Gamaliel', 'male'),
#  ('Garcia', 'male'),
#  ('Garcon', 'male'),
#  ('Gardener', 'male'),
#  ('Gardiner', 'male'),
#  ('Gardner', 'male'),
#  ('Garey', 'male'),
#  ('Garfield', 'male'),
#  ('Garfinkel', 'male'),
#  ('Garold', 'male'),
#  ('Garp', 'male'),
#  ('Garret', 'male'),
#  ('Garrett', 'male'),
#  ('Garrot', 'male'),
#  ('Garrott', 'male'),
#  ('Garry', 'male'),
#  ('Garth', 'male'),
#  ('Garv', 'male'),
#  ('Garvey', 'male'),
#  ('Garvin', 'male'),
#  ('Garvy', 'male'),
#  ('Garwin', 'male'),
#  ('Garwood', 'male'),
#  ('Gary', 'male'),
#  ('Gaspar', 'male'),
#  ('Gasper', 'male'),
#  ('Gaston', 'male'),
#  ('Gav', 'male'),
#  ('Gaven', 'male'),
#  ('Gavin', 'male'),
#  ('Gavriel', 'male'),
#  ('Gay', 'male'),
#  ('Gayle', 'male'),
#  ('Gearard', 'male'),
#  ('Gene', 'male'),
#  ('Geo', 'male'),
#  ('Geof', 'male'),
#  ('Geoff', 'male'),
#  ('Geoffrey', 'male'),
#  ('Geoffry', 'male'),
#  ('Georg', 'male'),
#  ('George', 'male'),
#  ('Georges', 'male'),
#  ('Georgia', 'male'),
#  ('Georgie', 'male'),
#  ('Georgy', 'male'),
#  ('Gerald', 'male'),
#  ('Geraldo', 'male'),
#  ('Gerard', 'male'),
#  ('Gere', 'male'),
#  ('Gerhard', 'male'),
#  ('Gerhardt', 'male'),
#  ('Geri', 'male'),
#  ('Germaine', 'male'),
#  ('Gerold', 'male'),
#  ('Gerome', 'male'),
#  ('Gerrard', 'male'),
#  ('Gerri', 'male'),
#  ('Gerrit', 'male'),
#  ('Gerry', 'male'),
#  ('Gershom', 'male'),
#  ('Gershon', 'male'),
#  ('Giacomo', 'male'),
#  ('Gian', 'male'),
#  ('Giancarlo', 'male'),
#  ('Giavani', 'male'),
#  ('Gibb', 'male'),
#  ('Gideon', 'male'),
#  ('Giff', 'male'),
#  ('Giffard', 'male'),
#  ('Giffer', 'male'),
#  ('Giffie', 'male'),
#  ('Gifford', 'male'),
#  ('Giffy', 'male'),
#  ('Gil', 'male'),
#  ('Gilbert', 'male'),
#  ('Gilberto', 'male'),
#  ('Gilburt', 'male'),
#  ('Giles', 'male'),
#  ('Gill', 'male'),
#  ('Gilles', 'male'),
#  ('Ginger', 'male'),
#  ('Gino', 'male'),
#  ('Giordano', 'male'),
#  ('Giorgi', 'male'),
#  ('Giorgio', 'male'),
#  ('Giovanne', 'male'),
#  ...]

# %%
len(names.words())
# Out:
# 7944

# %%
male = 0
female = 0
for pair in labeled_names:
    if pair[1] == 'male':
        male += 1
    elif pair[1] == 'female':
        female += 1
print("no. of male names :", male)
print("no. of female names :",female)
# Out:
# no. of male names : 2943
# no. of female names : 5001

# %%
import random

# %%
random.shuffle(labeled_names)
labeled_names
# Out:
# [('Chery', 'female'),
#  ('Gert', 'female'),
#  ('Stanleigh', 'male'),
#  ('Vicky', 'female'),
#  ('Zahara', 'female'),
#  ('Lilias', 'female'),
#  ('Corbin', 'male'),
#  ('Chauncey', 'male'),
#  ('Justina', 'female'),
#  ('Kaitlynn', 'female'),
#  ('Leese', 'female'),
#  ('Janis', 'female'),
#  ('Cherey', 'female'),
#  ('Willetta', 'female'),
#  ('Fidelity', 'female'),
#  ('Taber', 'male'),
#  ('Randal', 'male'),
#  ('Esteban', 'male'),
#  ('Wallache', 'male'),
#  ('Gordan', 'male'),
#  ('Klarika', 'female'),
#  ('Taylor', 'male'),
#  ('Donetta', 'female'),
#  ('Pavla', 'female'),
#  ('Burl', 'male'),
#  ('Faythe', 'female'),
#  ('Drake', 'male'),
#  ('Davina', 'female'),
#  ('Maury', 'male'),
#  ('Mel', 'male'),
#  ('Vilhelmina', 'female'),
#  ('Royce', 'male'),
#  ('Charmion', 'female'),
#  ('Norman', 'male'),
#  ('Wayne', 'male'),
#  ('Myrna', 'female'),
#  ('Valencia', 'female'),
#  ('Winfred', 'male'),
#  ('Winford', 'male'),
#  ('Julieta', 'female'),
#  ('Kiah', 'female'),
#  ('Jasper', 'male'),
#  ('Yonina', 'female'),
#  ('Jeniffer', 'female'),
#  ('Fredric', 'male'),
#  ('Cabrina', 'female'),
#  ('Stephannie', 'female'),
#  ('Veradis', 'female'),
#  ('Erminie', 'female'),
#  ('Lorianne', 'female'),
#  ('Lonnie', 'male'),
#  ('Fletch', 'male'),
#  ('Pennie', 'female'),
#  ('Warde', 'male'),
#  ('Roderigo', 'male'),
#  ('Audi', 'female'),
#  ('Edie', 'female'),
#  ('Mia', 'female'),
#  ('Finn', 'male'),
#  ('Shaun', 'female'),
#  ('Julian', 'male'),
#  ('Heida', 'female'),
#  ('Danila', 'female'),
#  ('Georgiana', 'female'),
#  ('Margarette', 'female'),
#  ('Ashleigh', 'female'),
#  ('Selina', 'female'),
#  ('Chelton', 'male'),
#  ('Vladamir', 'male'),
#  ('Tani', 'female'),
#  ('Marius', 'male'),
#  ('Don', 'male'),
#  ('Eddie', 'male'),
#  ('Brande', 'female'),
#  ('Yigal', 'male'),
#  ('Madelyn', 'female'),
#  ('Haywood', 'male'),
#  ('Alpa', 'female'),
#  ('Ronni', 'female'),
#  ('Ernestine', 'female'),
#  ('Katheryn', 'female'),
#  ('Nick', 'male'),
#  ('Myranda', 'female'),
#  ('Eliot', 'male'),
#  ('Jobye', 'female'),
#  ('Samuel', 'male'),
#  ('Deanne', 'female'),
#  ('Murray', 'male'),
#  ('Felecia', 'female'),
#  ('Con', 'female'),
#  ('Jerrine', 'female'),
#  ('Dotty', 'female'),
#  ('Merrill', 'female'),
#  ('Alina', 'female'),
#  ('Munmro', 'male'),
#  ('Cletus', 'male'),
#  ('Orion', 'male'),
#  ('Shannon', 'female'),
#  ('Chancey', 'male'),
#  ('Lucas', 'male'),
#  ('Glynda', 'female'),
#  ('Electra', 'female'),
#  ('Gregor', 'male'),
#  ('Marrissa', 'female'),
#  ('Bryce', 'male'),
#  ('Reilly', 'male'),
#  ('Nicolas', 'male'),
#  ('Chiquita', 'female'),
#  ('Zane', 'male'),
#  ('Sterne', 'male'),
#  ('Cristin', 'female'),
#  ('Melba', 'female'),
#  ('Cam', 'male'),
#  ('Karoline', 'female'),
#  ('Toni', 'female'),
#  ('Doll', 'female'),
#  ('Robbyn', 'female'),
#  ('Jeana', 'female'),
#  ('Constantinos', 'male'),
#  ('Winna', 'female'),
#  ('Tara', 'female'),
#  ('Dorris', 'female'),
#  ('Mirabelle', 'female'),
#  ('Cornellis', 'male'),
#  ('Rosalinde', 'female'),
#  ('Carlene', 'female'),
#  ('Mahalia', 'female'),
#  ('Quintus', 'male'),
#  ('Audre', 'female'),
#  ('Collin', 'male'),
#  ('Rosabella', 'female'),
#  ('Talia', 'female'),
#  ('Jermaine', 'female'),
#  ('Pandora', 'female'),
#  ('Erda', 'female'),
#  ('Emanuel', 'male'),
#  ('Parke', 'male'),
#  ('Lizzy', 'female'),
#  ('Demetrius', 'male'),
#  ('Rosario', 'female'),
#  ('Courtney', 'male'),
#  ('Henri', 'male'),
#  ('Ruthanne', 'female'),
#  ('Sollie', 'male'),
#  ('Maxfield', 'male'),
#  ('Jay', 'male'),
#  ('Dodie', 'female'),
#  ('Blakelee', 'female'),
#  ('Millisent', 'female'),
#  ('Antonietta', 'female'),
#  ('Oralee', 'female'),
#  ('Rey', 'male'),
#  ('Bartholemy', 'male'),
#  ('Gwenny', 'female'),
#  ('Judd', 'male'),
#  ('Randee', 'female'),
#  ('Merrie', 'female'),
#  ('Adi', 'female'),
#  ('Jacqueline', 'female'),
#  ('Tiffy', 'female'),
#  ('Jud', 'male'),
#  ('Gretal', 'female'),
#  ('Celestyn', 'female'),
#  ('Thaine', 'male'),
#  ('Arie', 'male'),
#  ('Shannan', 'male'),
#  ('Homer', 'male'),
#  ('Guglielma', 'female'),
#  ('Jemimah', 'female'),
#  ('Orsa', 'female'),
#  ('Lucius', 'male'),
#  ('Truda', 'female'),
#  ('Reginauld', 'male'),
#  ('Irita', 'female'),
#  ('Camila', 'female'),
#  ('Abby', 'male'),
#  ('Sammie', 'male'),
#  ('Betty', 'female'),
#  ('Wendel', 'male'),
#  ('Simonette', 'female'),
#  ('Javier', 'male'),
#  ('Marcello', 'male'),
#  ('Lucien', 'male'),
#  ('Deerdre', 'female'),
#  ('Elene', 'female'),
#  ('Ebonee', 'female'),
#  ('Stanford', 'male'),
#  ('Fawne', 'female'),
#  ('Niall', 'male'),
#  ('Averell', 'male'),
#  ('Jef', 'male'),
#  ('Dominique', 'male'),
#  ('Edward', 'male'),
#  ('Dido', 'female'),
#  ('Maribelle', 'female'),
#  ('Willie', 'female'),
#  ('Nani', 'female'),
#  ('Simonne', 'female'),
#  ('Geoffrey', 'male'),
#  ('Lucky', 'female'),
#  ('Jelene', 'female'),
#  ('Alexia', 'female'),
#  ('Babette', 'female'),
#  ('Marve', 'male'),
#  ('Kalli', 'female'),
#  ('Merill', 'male'),
#  ('Wilmer', 'male'),
#  ('Alfie', 'female'),
#  ('Catlin', 'female'),
#  ('Sascha', 'female'),
#  ('Merrel', 'male'),
#  ('Edith', 'female'),
#  ('Wain', 'male'),
#  ('Althea', 'female'),
#  ('Hakim', 'male'),
#  ('Terese', 'female'),
#  ('Edsel', 'male'),
#  ('Frankie', 'female'),
#  ('Marcile', 'female'),
#  ('Dieter', 'male'),
#  ('Petunia', 'female'),
#  ('Tandy', 'female'),
#  ('Felicity', 'female'),
#  ('Karalynn', 'female'),
#  ('Shurwood', 'male'),
#  ('Sean', 'female'),
#  ('Caresse', 'female'),
#  ('Madelaine', 'female'),
#  ('Robyn', 'female'),
#  ('Gladis', 'female'),
#  ('Rickey', 'male'),
#  ('Gisela', 'female'),
#  ('Dulcie', 'female'),
#  ('Kirsteni', 'female'),
#  ('Dorotea', 'female'),
#  ('Towny', 'male'),
#  ('Holley', 'female'),
#  ('Leanna', 'female'),
#  ('Minerva', 'female'),
#  ('Tabitha', 'female'),
#  ('Pate', 'male'),
#  ('Tedd', 'male'),
#  ('Alma', 'female'),
#  ('Berke', 'male'),
#  ('Torey', 'male'),
#  ('Loni', 'female'),
#  ('Bernard', 'male'),
#  ('Reeva', 'female'),
#  ('Grant', 'male'),
#  ('Janith', 'female'),
#  ('Moises', 'male'),
#  ('Lilllie', 'female'),
#  ('Margi', 'female'),
#  ('Yovonnda', 'female'),
#  ('Meagan', 'female'),
#  ('Nanine', 'female'),
#  ('Renae', 'female'),
#  ('Alec', 'male'),
#  ('Vincent', 'male'),
#  ('Carmen', 'female'),
#  ('Marie', 'female'),
#  ('Vic', 'male'),
#  ('Lorrie', 'male'),
#  ('Dulsea', 'female'),
#  ('Leah', 'female'),
#  ('Boniface', 'male'),
#  ('Lydie', 'female'),
#  ('Noam', 'male'),
#  ('Timmie', 'female'),
#  ('Dominica', 'female'),
#  ('Teodorico', 'male'),
#  ('Sile', 'female'),
#  ('Camilla', 'female'),
#  ('Evangelia', 'female'),
#  ('Pacifica', 'female'),
#  ('Kerri', 'female'),
#  ('Eunice', 'female'),
#  ('Philip', 'male'),
#  ('Pam', 'female'),
#  ('Cristina', 'female'),
#  ('Flossi', 'female'),
#  ('Jodie', 'female'),
#  ('Sanderson', 'male'),
#  ('Collins', 'male'),
#  ('Antonia', 'female'),
#  ('Blanche', 'female'),
#  ('Myles', 'male'),
#  ('Pierette', 'female'),
#  ('Steffane', 'female'),
#  ('Susanna', 'female'),
#  ('Sharyl', 'female'),
#  ('Emelina', 'female'),
#  ('Zara', 'female'),
#  ('Chaddie', 'male'),
#  ('Kai', 'female'),
#  ('Pincus', 'male'),
#  ('Roosevelt', 'male'),
#  ('Bette', 'female'),
#  ('Reyna', 'female'),
#  ('Ritchie', 'male'),
#  ('Sibley', 'female'),
#  ('Ashlee', 'female'),
#  ('Sylvan', 'male'),
#  ('Gwenore', 'female'),
#  ('Gladi', 'female'),
#  ('Betti', 'female'),
#  ('Charlie', 'male'),
#  ('Catha', 'female'),
#  ('Timothea', 'female'),
#  ('Lamar', 'male'),
#  ('Carmina', 'female'),
#  ('Brandea', 'female'),
#  ('Trixy', 'female'),
#  ('Gerald', 'male'),
#  ('Bel', 'female'),
#  ('Aaron', 'male'),
#  ('Netty', 'female'),
#  ('Thaddus', 'male'),
#  ('May', 'female'),
#  ('Pamella', 'female'),
#  ('Rex', 'male'),
#  ('Judy', 'female'),
#  ('Hewe', 'male'),
#  ('Clementia', 'female'),
#  ('Lazarus', 'male'),
#  ('Nanette', 'female'),
#  ('Adolfo', 'male'),
#  ('Margette', 'female'),
#  ('Sidoney', 'female'),
#  ('Clemens', 'male'),
#  ('Janelle', 'female'),
#  ('Libbie', 'female'),
#  ('Elmer', 'male'),
#  ('Kayla', 'female'),
#  ('Ethel', 'female'),
#  ('Claudetta', 'female'),
#  ('Marlyn', 'female'),
#  ('Wendeline', 'female'),
#  ('Alex', 'female'),
#  ('Sandro', 'male'),
#  ('Goldina', 'female'),
#  ('Lauralee', 'female'),
#  ('Dyann', 'female'),
#  ('Andy', 'female'),
#  ('Jenette', 'female'),
#  ('Ardene', 'female'),
#  ('Dyson', 'male'),
#  ('Dede', 'female'),
#  ('Fredericka', 'female'),
#  ('Urbano', 'male'),
#  ('Hew', 'male'),
#  ('Theo', 'female'),
#  ('Rutherford', 'male'),
#  ('Ozzy', 'male'),
#  ('Randie', 'male'),
#  ('Darby', 'female'),
#  ('Arabele', 'female'),
#  ('Lianna', 'female'),
#  ('Ketti', 'female'),
#  ('Herculie', 'male'),
#  ('Fatima', 'female'),
#  ('Reece', 'male'),
#  ('Reggis', 'male'),
#  ('Anatoly', 'male'),
#  ('Fanni', 'female'),
#  ('Dorena', 'female'),
#  ('Laila', 'female'),
#  ('Hart', 'male'),
#  ('Ambros', 'male'),
#  ('Holly', 'male'),
#  ('Harrie', 'female'),
#  ('Sammy', 'female'),
#  ('Darcy', 'male'),
#  ('Kakalina', 'female'),
#  ('Crysta', 'female'),
#  ('Amalea', 'female'),
#  ('Stearn', 'male'),
#  ('Grissel', 'female'),
#  ('Myrtia', 'female'),
#  ('Rustin', 'male'),
#  ('Robin', 'female'),
#  ('Giacinta', 'female'),
#  ('Ransell', 'male'),
#  ('Maddy', 'male'),
#  ('Jephthah', 'male'),
#  ('Sibylla', 'female'),
#  ('Durante', 'male'),
#  ('Ragnar', 'male'),
#  ('Dacey', 'female'),
#  ('Vachel', 'male'),
#  ('Roda', 'female'),
#  ('Kyle', 'male'),
#  ('Inci', 'female'),
#  ('Clay', 'male'),
#  ('Madlin', 'female'),
#  ('Roni', 'male'),
#  ('Urson', 'male'),
#  ('Eduardo', 'male'),
#  ('Ernesta', 'female'),
#  ('Pollyanna', 'female'),
#  ('Christean', 'female'),
#  ('Sonya', 'female'),
#  ('Anni', 'female'),
#  ('Martica', 'female'),
#  ('Josef', 'male'),
#  ('Romain', 'male'),
#  ('Ehud', 'male'),
#  ('Joell', 'female'),
#  ('Dora', 'female'),
#  ('Lita', 'female'),
#  ('Randolph', 'male'),
#  ('Everett', 'male'),
#  ('Clint', 'male'),
#  ('Tim', 'female'),
#  ('Paule', 'female'),
#  ('Georgeta', 'female'),
#  ('Rees', 'male'),
#  ('Gunter', 'male'),
#  ('Riki', 'female'),
#  ('Marcel', 'male'),
#  ('Leeanne', 'female'),
#  ('Lazare', 'male'),
#  ('Shea', 'male'),
#  ('Tim', 'male'),
#  ('Alisha', 'female'),
#  ('Georgeanna', 'female'),
#  ('Saunder', 'male'),
#  ('Ingemar', 'male'),
#  ('Woodie', 'male'),
#  ('Carlos', 'male'),
#  ('Cherye', 'female'),
#  ('Raphaela', 'female'),
#  ('Peg', 'female'),
#  ('Melessa', 'female'),
#  ('Tommy', 'female'),
#  ('Lynna', 'female'),
#  ('Townsend', 'male'),
#  ('Bernette', 'female'),
#  ('Brenn', 'female'),
#  ('Hayward', 'male'),
#  ('Murielle', 'female'),
#  ('Alyse', 'female'),
#  ('Pail', 'male'),
#  ('Edy', 'female'),
#  ('Charmian', 'female'),
#  ('Ismail', 'male'),
#  ('Kirsten', 'female'),
#  ('Flo', 'female'),
#  ('Luciana', 'female'),
#  ('Donica', 'female'),
#  ('Dari', 'female'),
#  ('Domenico', 'male'),
#  ('Elspeth', 'female'),
#  ('Wittie', 'male'),
#  ('Cherie', 'female'),
#  ('Aleks', 'male'),
#  ('Zechariah', 'male'),
#  ('Shani', 'female'),
#  ('Bernhard', 'male'),
#  ('Ellette', 'female'),
#  ('Leora', 'female'),
#  ('Zerk', 'male'),
#  ('Zelda', 'female'),
#  ('Mauritz', 'male'),
#  ('Leonerd', 'male'),
#  ('Anita', 'female'),
#  ('Renault', 'male'),
#  ('Neda', 'female'),
#  ('Wadsworth', 'male'),
#  ('Westbrooke', 'male'),
#  ('Agnesse', 'female'),
#  ('Lucy', 'female'),
#  ('Jordan', 'female'),
#  ('Job', 'male'),
#  ('Audra', 'female'),
#  ('Kathie', 'female'),
#  ('Joane', 'female'),
#  ('Shena', 'female'),
#  ('Masha', 'female'),
#  ('Bengt', 'male'),
#  ('Tremain', 'male'),
#  ('Pauletta', 'female'),
#  ('Leorah', 'female'),
#  ('Napoleon', 'male'),
#  ('Susanne', 'female'),
#  ('Karsten', 'male'),
#  ('Viva', 'female'),
#  ('Stinky', 'male'),
#  ('Maya', 'female'),
#  ('Weber', 'male'),
#  ('Burgess', 'male'),
#  ('Alane', 'female'),
#  ('Salem', 'male'),
#  ('Antonin', 'male'),
#  ('Trudy', 'female'),
#  ('Leanne', 'female'),
#  ('Gabriele', 'male'),
#  ('Lucine', 'female'),
#  ('Vinnie', 'female'),
#  ('Layla', 'female'),
#  ('Salli', 'female'),
#  ('Katey', 'female'),
#  ('Ethelind', 'female'),
#  ('Jany', 'female'),
#  ('Berenice', 'female'),
#  ('Karel', 'male'),
#  ('Dean', 'male'),
#  ('Jillane', 'female'),
#  ('Cordelia', 'female'),
#  ('Gifford', 'male'),
#  ('Gera', 'female'),
#  ('Kacey', 'female'),
#  ('Nelia', 'female'),
#  ('Constantine', 'male'),
#  ('Alston', 'male'),
#  ('Sibeal', 'female'),
#  ('Ross', 'male'),
#  ('Stern', 'male'),
#  ('Ella', 'female'),
#  ('Alice', 'female'),
#  ('Jannel', 'female'),
#  ('Whitaker', 'male'),
#  ('Anatol', 'male'),
#  ('Donald', 'male'),
#  ('Beau', 'female'),
#  ('Torr', 'male'),
#  ('Ivette', 'female'),
#  ('Perla', 'female'),
#  ('Corilla', 'female'),
#  ('Lorrin', 'female'),
#  ('Patrik', 'male'),
#  ('Larissa', 'female'),
#  ('Rani', 'female'),
#  ('Sharie', 'female'),
#  ('Paulita', 'female'),
#  ('Danice', 'female'),
#  ('Waite', 'male'),
#  ('Davita', 'female'),
#  ('Barron', 'male'),
#  ('Kylie', 'female'),
#  ('Mildrid', 'female'),
#  ('Lorilee', 'female'),
#  ('Jethro', 'male'),
#  ('Alexandrina', 'female'),
#  ('Jonell', 'female'),
#  ('Charlton', 'male'),
#  ('Blair', 'male'),
#  ('Tomiko', 'female'),
#  ('Holly', 'female'),
#  ('Connolly', 'male'),
#  ('Rachael', 'female'),
#  ('Stesha', 'female'),
#  ('Thadeus', 'male'),
#  ('Elisha', 'female'),
#  ('Charleton', 'male'),
#  ('Godfrey', 'male'),
#  ('Conan', 'male'),
#  ('Matti', 'female'),
#  ('Skip', 'male'),
#  ('Anett', 'female'),
#  ('Henrietta', 'female'),
#  ('Kylila', 'female'),
#  ('Kaile', 'female'),
#  ('Burke', 'male'),
#  ('Ginnifer', 'female'),
#  ('Melodie', 'female'),
#  ('Sharra', 'female'),
#  ('Florie', 'female'),
#  ('Ware', 'male'),
#  ('Wit', 'male'),
#  ('Sanson', 'male'),
#  ('Illa', 'female'),
#  ('Odilia', 'female'),
#  ('Starr', 'female'),
#  ('Gerhardt', 'male'),
#  ('Madona', 'female'),
#  ('Harmon', 'male'),
#  ('Flower', 'female'),
#  ('Lindsay', 'female'),
#  ('Barbette', 'female'),
#  ('Mark', 'male'),
#  ('Pet', 'female'),
#  ('Siouxie', 'female'),
#  ('Faye', 'female'),
#  ('Alphonse', 'male'),
#  ('Yolande', 'female'),
#  ('Laurene', 'female'),
#  ('Tuckie', 'male'),
#  ('Endora', 'female'),
#  ('Lissa', 'female'),
#  ('Paola', 'female'),
#  ('Carolan', 'female'),
#  ('Griffith', 'male'),
#  ('Madelene', 'female'),
#  ('Catherine', 'female'),
#  ('Shane', 'female'),
#  ('Gearard', 'male'),
#  ('Ferdinand', 'male'),
#  ('Leonore', 'female'),
#  ('Savina', 'female'),
#  ('Hercules', 'male'),
#  ('Anastasia', 'female'),
#  ('Anestassia', 'female'),
#  ('Andrea', 'male'),
#  ('Charlot', 'female'),
#  ('Anselma', 'female'),
#  ('Rory', 'male'),
#  ('Estrellita', 'female'),
#  ('Georgianne', 'female'),
#  ('Morry', 'male'),
#  ('Len', 'male'),
#  ('Ursuline', 'female'),
#  ('Dyna', 'female'),
#  ('Theada', 'female'),
#  ('Peggie', 'female'),
#  ('Alla', 'female'),
#  ('Anstice', 'female'),
#  ('Prent', 'male'),
#  ('Eirena', 'female'),
#  ('Stan', 'male'),
#  ('Olly', 'female'),
#  ('Herb', 'male'),
#  ('Tybalt', 'male'),
#  ('Millicent', 'female'),
#  ('Towney', 'male'),
#  ('Jean-Marc', 'male'),
#  ('Rebekkah', 'female'),
#  ('Emyle', 'female'),
#  ('Bertrand', 'male'),
#  ('Konstanze', 'female'),
#  ('Biddy', 'female'),
#  ('Tedda', 'female'),
#  ('Phillipe', 'male'),
#  ('Toby', 'male'),
#  ('Candide', 'female'),
#  ('Shawna', 'female'),
#  ('Shaw', 'male'),
#  ('Grace', 'male'),
#  ('Moria', 'female'),
#  ('Rivalee', 'female'),
#  ('Ximenes', 'male'),
#  ('Calley', 'female'),
#  ('Sheffy', 'male'),
#  ('Antoinette', 'female'),
#  ('Welch', 'male'),
#  ('Agnola', 'female'),
#  ('Jaquelyn', 'female'),
#  ('Virginia', 'female'),
#  ('Courtenay', 'female'),
#  ('Casi', 'female'),
#  ('Golda', 'female'),
#  ('Berni', 'female'),
#  ('Sela', 'female'),
#  ('Lynde', 'female'),
#  ('Boyd', 'male'),
#  ('Lurleen', 'female'),
#  ('Mable', 'female'),
#  ('Calypso', 'female'),
#  ('Marianne', 'female'),
#  ('Crawford', 'male'),
#  ('Etti', 'female'),
#  ('Alvira', 'female'),
#  ('Lizabeth', 'female'),
#  ('Durant', 'male'),
#  ('Briggs', 'male'),
#  ('Kaleena', 'female'),
#  ('Marlene', 'female'),
#  ('Kittie', 'female'),
#  ('Nettie', 'female'),
#  ('Karlen', 'female'),
#  ('Bryant', 'male'),
#  ('Darcey', 'female'),
#  ('Jessa', 'female'),
#  ('Kathleen', 'female'),
#  ('Waiter', 'male'),
#  ('Ferdie', 'male'),
#  ('Winslow', 'male'),
#  ('Ace', 'male'),
#  ('Nevins', 'male'),
#  ('Ty', 'male'),
#  ('Lavinie', 'female'),
#  ('Marshal', 'male'),
#  ('Scott', 'male'),
#  ('Muhammad', 'male'),
#  ('Geneva', 'female'),
#  ('Anurag', 'male'),
#  ('Claybourne', 'male'),
#  ('Mahmoud', 'male'),
#  ('Piggy', 'male'),
#  ('Claire', 'female'),
#  ('Allianora', 'female'),
#  ('Shannen', 'female'),
#  ('Avi', 'male'),
#  ('Esme', 'male'),
#  ('Charlene', 'female'),
#  ('Germana', 'female'),
#  ('Myron', 'male'),
#  ('Clerissa', 'female'),
#  ('Orin', 'male'),
#  ('Lucila', 'female'),
#  ('Theodora', 'female'),
#  ('Jolie', 'female'),
#  ('Trix', 'female'),
#  ('Penrod', 'male'),
#  ('Netta', 'female'),
#  ('Irina', 'female'),
#  ('Shandy', 'female'),
#  ('Kelci', 'female'),
#  ('Timmy', 'female'),
#  ('Anabelle', 'female'),
#  ('Marit', 'female'),
#  ('Irwin', 'male'),
#  ('Olivie', 'female'),
#  ('Rochette', 'female'),
#  ('Voltaire', 'male'),
#  ('Issy', 'female'),
#  ('Maurine', 'female'),
#  ('Andrus', 'male'),
#  ('Glynnis', 'female'),
#  ('Blondy', 'female'),
#  ('Beatriz', 'female'),
#  ('Rabbi', 'male'),
#  ('Bert', 'male'),
#  ('Vally', 'female'),
#  ('Carry', 'female'),
#  ('Verine', 'female'),
#  ('Shalna', 'female'),
#  ('Fabrice', 'female'),
#  ('Levin', 'male'),
#  ('Alix', 'male'),
#  ('Claudette', 'female'),
#  ('Laural', 'female'),
#  ('Amalee', 'female'),
#  ('Muffin', 'female'),
#  ('Del', 'female'),
#  ('Kaitlin', 'female'),
#  ('Marc', 'male'),
#  ('Gerda', 'female'),
#  ('Hyatt', 'male'),
#  ('Tresa', 'female'),
#  ('Jerome', 'male'),
#  ('Osgood', 'male'),
#  ('Zorah', 'female'),
#  ('Selby', 'male'),
#  ('Stevana', 'female'),
#  ('Elita', 'female'),
#  ('Julienne', 'female'),
#  ('Martha', 'female'),
#  ('Mariellen', 'female'),
#  ('Toma', 'female'),
#  ('Chet', 'male'),
#  ('Wileen', 'female'),
#  ('Kraig', 'male'),
#  ('Lola', 'female'),
#  ('Aleen', 'female'),
#  ('Matilda', 'female'),
#  ('Mora', 'female'),
#  ('Joli', 'female'),
#  ('Chad', 'male'),
#  ('Demetre', 'male'),
#  ('Ervin', 'male'),
#  ('Isaak', 'male'),
#  ('Stacey', 'female'),
#  ('Min', 'female'),
#  ('Jeralee', 'female'),
#  ('Lura', 'female'),
#  ('Riannon', 'female'),
#  ('Marnia', 'female'),
#  ('Orelee', 'female'),
#  ('Wakefield', 'male'),
#  ('Hal', 'male'),
#  ('Jennilee', 'female'),
#  ('Dela', 'female'),
#  ('Carmine', 'male'),
#  ('Merry', 'male'),
#  ('Nikolai', 'male'),
#  ('Enrica', 'female'),
#  ('Therese', 'female'),
#  ('Joana', 'female'),
#  ('Phillip', 'male'),
#  ('Gibb', 'male'),
#  ('Shumeet', 'male'),
#  ('Ambrosio', 'male'),
#  ('Karola', 'female'),
#  ('Lily', 'female'),
#  ('Brant', 'male'),
#  ('Micheline', 'female'),
#  ('Camile', 'female'),
#  ('Yetta', 'female'),
#  ('Ansell', 'male'),
#  ('Suki', 'female'),
#  ('Alister', 'male'),
#  ('Aleck', 'male'),
#  ('Nikki', 'female'),
#  ('Lil', 'female'),
#  ('Sigrid', 'female'),
#  ('Gale', 'male'),
#  ('Philbert', 'male'),
#  ('Kelly', 'male'),
#  ('Frazier', 'male'),
#  ('Orazio', 'male'),
#  ('Sharla', 'female'),
#  ('Bride', 'female'),
#  ('Sibella', 'female'),
#  ('Solange', 'female'),
#  ('Anais', 'female'),
#  ('Shelba', 'female'),
#  ('Manuel', 'male'),
#  ('Frederic', 'male'),
#  ('Mallory', 'female'),
#  ('Maia', 'female'),
#  ('Witty', 'male'),
#  ('Alphonso', 'male'),
#  ('Husein', 'male'),
#  ('Urbain', 'male'),
#  ('Norma', 'female'),
#  ('Amberly', 'female'),
#  ('August', 'male'),
#  ('Mikako', 'female'),
#  ('Babara', 'female'),
#  ('Robinia', 'female'),
#  ('Kelwin', 'male'),
#  ('Alfie', 'male'),
#  ('Tomlin', 'male'),
#  ('Trisha', 'female'),
#  ('Ardath', 'female'),
#  ('Nealon', 'male'),
#  ('Daniella', 'female'),
#  ('Tilda', 'female'),
#  ('Elaina', 'female'),
#  ('Jerrilee', 'female'),
#  ('Johnette', 'female'),
#  ('Edie', 'male'),
#  ('Tannie', 'male'),
#  ('Courtney', 'female'),
#  ('Othilie', 'female'),
#  ('Darth', 'male'),
#  ('Ekaterina', 'female'),
#  ('Thain', 'male'),
#  ('Shalom', 'male'),
#  ('Rey', 'female'),
#  ('Theo', 'male'),
#  ('Elisha', 'male'),
#  ('Lina', 'female'),
#  ('Casey', 'female'),
#  ('Sinead', 'female'),
#  ('Philly', 'female'),
#  ('Consuelo', 'female'),
#  ('Page', 'female'),
#  ('Tracy', 'female'),
#  ('Abbi', 'female'),
#  ('Lou', 'male'),
#  ('Acacia', 'female'),
#  ('Connie', 'male'),
#  ('Kimberlyn', 'female'),
#  ('Goldie', 'female'),
#  ('Darda', 'female'),
#  ('Ahmed', 'male'),
#  ('Erastus', 'male'),
#  ('Jemie', 'female'),
#  ('Josephina', 'female'),
#  ('Theobald', 'male'),
#  ('Eadie', 'female'),
#  ('Ernesto', 'male'),
#  ('Charley', 'male'),
#  ('Karylin', 'female'),
#  ('Susan', 'female'),
#  ('Bayard', 'male'),
#  ('Pru', 'female'),
#  ('Glenna', 'female'),
#  ('Katti', 'female'),
#  ('Marry', 'female'),
#  ('Rona', 'female'),
#  ('Josefina', 'female'),
#  ('Berthe', 'female'),
#  ('Willmott', 'male'),
#  ('Ludwig', 'male'),
#  ('Nealson', 'male'),
#  ('Freda', 'female'),
#  ('Nell', 'female'),
#  ('Joe', 'male'),
#  ('Michaelina', 'female'),
#  ('Jodie', 'male'),
#  ('Vikki', 'female'),
#  ('Burta', 'female'),
#  ('Tabbie', 'female'),
#  ('Adorne', 'female'),
#  ('Ellis', 'male'),
#  ('Emmit', 'male'),
#  ('Noel', 'female'),
#  ('Israel', 'male'),
#  ('Pavel', 'male'),
#  ('Guendolen', 'female'),
#  ('Lambert', 'male'),
#  ('Clarence', 'male'),
#  ('Darleen', 'female'),
#  ('Marlon', 'male'),
#  ('Patrice', 'female'),
#  ('Averyl', 'female'),
#  ('Apostolos', 'male'),
#  ('Rozelle', 'female'),
#  ('Ravil', 'male'),
#  ('Kalil', 'male'),
#  ('Lebbie', 'female'),
#  ('Rodd', 'male'),
#  ('Wash', 'male'),
#  ('Austin', 'female'),
#  ('Constanta', 'female'),
#  ('Marni', 'female'),
#  ('Kira', 'female'),
#  ('Siana', 'female'),
#  ('Andrea', 'female'),
#  ('Delphina', 'female'),
#  ('Brunella', 'female'),
#  ('Lizzie', 'female'),
#  ('Patricia', 'female'),
#  ('Victor', 'male'),
#  ('Enoch', 'male'),
#  ('Elise', 'female'),
#  ('Gus', 'male'),
#  ('Thornton', 'male'),
#  ('Tommy', 'male'),
#  ('Enya', 'female'),
#  ('Emmery', 'male'),
#  ('Connie', 'female'),
#  ('Clancy', 'male'),
#  ('Skye', 'male'),
#  ('Rinaldo', 'male'),
#  ('Agnes', 'female'),
#  ('Iona', 'female'),
#  ('Nikki', 'male'),
#  ('Kelsi', 'female'),
#  ('Vivianne', 'female'),
#  ('Alain', 'male'),
#  ('Fiann', 'female'),
#  ('Matias', 'male'),
#  ('Ike', 'female'),
#  ('Gilbert', 'male'),
#  ('Germaine', 'male'),
#  ('Nana', 'female'),
#  ('Ian', 'male'),
#  ('Fanchon', 'female'),
#  ('Lelia', 'female'),
#  ('Geraldina', 'female'),
#  ('Eliott', 'male'),
#  ('Ivett', 'female'),
#  ('Gay', 'female'),
#  ('Kerrin', 'female'),
#  ('Rowe', 'female'),
#  ('Crissy', 'female'),
#  ('Hari', 'male'),
#  ('Salmon', 'male'),
#  ('Lise', 'female'),
#  ('Vanda', 'female'),
#  ('Winnifred', 'female'),
#  ('Marcellus', 'male'),
#  ('Daphne', 'female'),
#  ('Robinet', 'female'),
#  ('Dorette', 'female'),
#  ('Benita', 'female'),
#  ('Hali', 'female'),
#  ('Karee', 'female'),
#  ('Moll', 'female'),
#  ('Raye', 'female'),
#  ('Irvin', 'male'),
#  ('Rina', 'female'),
#  ('Kimbra', 'female'),
#  ('Kalina', 'female'),
#  ('Ara', 'female'),
#  ('Elyse', 'female'),
#  ('Thia', 'female'),
#  ('Dinnie', 'female'),
#  ('Izak', 'male'),
#  ('Katleen', 'female'),
#  ('Marv', 'male'),
#  ('Casey', 'male'),
#  ('Wandis', 'female'),
#  ('Osbourn', 'male'),
#  ('Michele', 'male'),
#  ('Gratia', 'female'),
#  ('Cliff', 'male'),
#  ('Pearline', 'female'),
#  ('Wilfrid', 'male'),
#  ('Elke', 'female'),
#  ('Alexine', 'female'),
#  ('Carlynne', 'female'),
#  ('Dyanna', 'female'),
#  ('Trace', 'male'),
#  ('Arvind', 'male'),
#  ('Obadiah', 'male'),
#  ('Anette', 'female'),
#  ('Ambrosia', 'female'),
#  ('Stephani', 'female'),
#  ('Corrinne', 'female'),
#  ('Marjie', 'female'),
#  ('Michele', 'female'),
#  ('Wilona', 'female'),
#  ('Fanechka', 'female'),
#  ('Dona', 'female'),
#  ('Mikhail', 'male'),
#  ...]

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'x'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'g'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'u'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'z'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'x'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'u'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'v'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ...]

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, test_set))*100)
# Out:
# Classifier accuracy percent: 75.4
